# %% [markdown]
# **1. Leer el archivo CO2 emissions.csv**

# %%
import pandas as pd

# Leer el archivo CSV
df = pd.read_csv('CO2 emissions.csv')

# Mostrar las primeras filas del dataframe
print(df.head())
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0         2.0          4                   9.9                  6.7
# 1         2.4          4                  11.2                  7.7
# 2         1.5          4                   6.0                  5.8
# 3         3.5          6                  12.7                  9.1
# 4         3.5          6                  12.1                  8.7
#
#    CO2EMISSIONS
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# **2. Seleccionar aleatoriamente el 80% del conjunto de datos para entrenar y el 20% restante para las pruebas**

# %%
from sklearn.model_selection import train_test_split

# Separar variables independientes y dependientes
X = df[['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY', 'FUELCONSUMPTION_HWY']]
y = df['CO2EMISSIONS']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# **3. Utilizar una estrategia para normalizar los datos**

# %%
from sklearn.preprocessing import StandardScaler

# Estandarizar las variables
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# **4. Construir 5 redes neuronales variando los hiperparámetros y mostrar los resultados**

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# Definir los hiperparámetros a probar
activations = ['identity', 'logistic', 'tanh', 'relu']
solvers = ['lbfgs', 'sgd', 'adam']
hidden_layer_sizes = [(50,), (100,), (50, 50), (100, 50), (100, 100)]

results = []

# Probar diferentes combinaciones de hiperparámetros
for activation in activations:
    for solver in solvers:
        for hidden_layers in hidden_layer_sizes:
            mlp = MLPClassifier(activation=activation, solver=solver, hidden_layer_sizes=hidden_layers, random_state=123)
            mlp.fit(X_train, y_train)
            y_pred = mlp.predict(X_test)
            accuracy = accuracy_score(y_test, y_pred)
            conf_matrix = confusion_matrix(y_test, y_pred)
            results.append({
                'activation': activation,
                'solver': solver,
                'hidden_layers': hidden_layers,
                'accuracy': accuracy,
                'conf_matrix': conf_matrix
            })

# Mostrar los resultados en una tabla
results_df = pd.DataFrame(results, columns=['activation', 'solver', 'hidden_layers', 'accuracy', 'conf_matrix'])
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#    activation solver hidden_layers  accuracy           conf_matrix
# 0    identity  lbfgs         (50,)  0.915888   [[106, 9], [9, 90]]
# 1    identity  lbfgs        (100,)  0.915888   [[106, 9], [9, 90]]
# 2    identity  lbfgs      (50, 50)  0.915888   [[106, 9], [9, 90]]
# 3    identity  lbfgs     (100, 50)  0.915888   [[106, 9], [9, 90]]
# 4    identity  lbfgs    (100, 100)  0.915888   [[106, 9], [9, 90]]
# 5    identity    sgd         (50,)  0.920561  [[105, 10], [7, 92]]
# 6    identity    sgd        (100,)  0.920561  [[104, 11], [6, 93]]
# 7    identity    sgd      (50, 50)  0.925234   [[106, 9], [7, 92]]
# 8    identity    sgd     (100, 50)  0.925234  [[105, 10], [6, 93]]
# 9    identity    sgd    (100, 100)  0.929907   [[106, 9], [6, 93]]
# 10   identity   adam         (50,)  0.925234   [[106, 9], [7, 92]]
# 11   identity   adam        (100,)  0.939252   [[108, 7], [6, 93]]
# 12   identity   adam      (50, 50)  0.934579   [[107, 8], [6, 93]]
# 13   identity   adam     (100, 50)  0.925234   [[106, 9], [7, 92]]
# 14   identity   adam    (100, 100)  0.929907   [[106, 9], [6, 93]]
# 15   logistic  lbfgs         (50,)  0.976636   [[114, 1], [4, 95]]
# 16   logistic  lbfgs        (100,)  0.962617   [[113, 2], [6, 93]]
# 17   logistic  lbfgs      (50, 50)  0.962617   [[111, 4], [4, 95]]
# 18   logistic  lbfgs     (100, 50)  0.939252   [[111, 4], [9, 90]]
# 19   logistic  lbfgs    (100, 100)  0.953271   [[111, 4], [6, 93]]
# 20   logistic    sgd         (50,)  0.883178  [[108, 7], [18, 81]]
# 21   logistic    sgd        (100,)  0.883178  [[108, 7], [18, 81]]
# 22   logistic    sgd      (50, 50)  0.537383   [[115, 0], [99, 0]]
# 23   logistic    sgd     (100, 50)  0.537383   [[115, 0], [99, 0]]
# 24   logistic    sgd    (100, 100)  0.537383   [[115, 0], [99, 0]]
# 25   logistic   adam         (50,)  0.920561  [[104, 11], [6, 93]]
# 26   logistic   adam        (100,)  0.925234   [[106, 9], [7, 92]]
# 27   logistic   adam      (50, 50)  0.934579   [[107, 8], [6, 93]]
# 28   logistic   adam     (100, 50)  0.934579  [[104, 11], [3, 96]]
# 29   logistic   adam    (100, 100)  0.939252  [[105, 10], [3, 96]]
# 30       tanh  lbfgs         (50,)  0.971963   [[112, 3], [3, 96]]
# 31       tanh  lbfgs        (100,)  0.957944   [[112, 3], [6, 93]]
# 32       tanh  lbfgs      (50, 50)  0.967290   [[110, 5], [2, 97]]
# 33       tanh  lbfgs     (100, 50)  0.967290   [[113, 2], [5, 94]]
# 34       tanh  lbfgs    (100, 100)  0.962617   [[110, 5], [3, 96]]
# 35       tanh    sgd         (50,)  0.920561  [[105, 10], [7, 92]]
# 36       tanh    sgd        (100,)  0.920561  [[104, 11], [6, 93]]
# 37       tanh    sgd      (50, 50)  0.925234   [[106, 9], [7, 92]]
# 38       tanh    sgd     (100, 50)  0.925234  [[105, 10], [6, 93]]
# 39       tanh    sgd    (100, 100)  0.929907   [[106, 9], [6, 93]]
# 40       tanh   adam         (50,)  0.934579   [[107, 8], [6, 93]]
# 41       tanh   adam        (100,)  0.929907   [[107, 8], [7, 92]]
# 42       tanh   adam      (50, 50)  0.934579   [[106, 9], [5, 94]]
# 43       tanh   adam     (100, 50)  0.939252  [[105, 10], [3, 96]]
# 44       tanh   adam    (100, 100)  0.962617   [[111, 4], [4, 95]]
# 45       relu  lbfgs         (50,)  0.953271   [[111, 4], [6, 93]]
# 46       relu  lbfgs        (100,)  0.957944   [[112, 3], [6, 93]]
# 47       relu  lbfgs      (50, 50)  0.971963   [[112, 3], [3, 96]]
# 48       relu  lbfgs     (100, 50)  0.948598   [[110, 5], [6, 93]]
# 49       relu  lbfgs    (100, 100)  0.962617   [[112, 3], [5, 94]]
# 50       relu    sgd         (50,)  0.925234  [[105, 10], [6, 93]]
# 51       relu    sgd        (100,)  0.920561  [[104, 11], [6, 93]]
# 52       relu    sgd      (50, 50)  0.929907   [[106, 9], [6, 93]]
# 53       relu    sgd     (100, 50)  0.920561  [[104, 11], [6, 93]]
# 54       relu    sgd    (100, 100)  0.925234  [[105, 10], [6, 93]]
# 55       relu   adam         (50,)  0.943925   [[107, 8], [4, 95]]
# 56       relu   adam        (100,)  0.934579   [[106, 9], [5, 94]]
# 57       relu   adam      (50, 50)  0.948598   [[110, 5], [6, 93]]
# 58       relu   adam     (100, 50)  0.967290   [[109, 6], [1, 98]]
# 59       relu   adam    (100, 100)  0.967290   [[112, 3], [4, 95]]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# **5. Mostrar las cinco matrices de confusión y el resumen de accuracy**

# %%
# Mostrar las cinco matrices de confusión
for i, result in enumerate(results):
    print(f"Configuration {i+1}: Activation={result['activation']}, Solver={result['solver']}, Hidden Layers={result['hidden_layers']}")
    print(f"Accuracy: {result['accuracy']}")
    print("Confusion Matrix:")
    print(result['conf_matrix'])
    print("\n")

# Crear una tabla resumen
summary_table = results_df[['activation', 'solver', 'hidden_layers', 'accuracy']]
print(summary_table)
# Out:
# Configuration 1: Activation=identity, Solver=lbfgs, Hidden Layers=(50,)
# Accuracy: 0.9158878504672897
# Confusion Matrix:
# [[106   9]
#  [  9  90]]
#
#
# Configuration 2: Activation=identity, Solver=lbfgs, Hidden Layers=(100,)
# Accuracy: 0.9158878504672897
# Confusion Matrix:
# [[106   9]
#  [  9  90]]
#
#
# Configuration 3: Activation=identity, Solver=lbfgs, Hidden Layers=(50, 50)
# Accuracy: 0.9158878504672897
# Confusion Matrix:
# [[106   9]
#  [  9  90]]
#
#
# Configuration 4: Activation=identity, Solver=lbfgs, Hidden Layers=(100, 50)
# Accuracy: 0.9158878504672897
# Confusion Matrix:
# [[106   9]
#  [  9  90]]
#
#
# Configuration 5: Activation=identity, Solver=lbfgs, Hidden Layers=(100, 100)
# Accuracy: 0.9158878504672897
# Confusion Matrix:
# [[106   9]
#  [  9  90]]
#
#
# Configuration 6: Activation=identity, Solver=sgd, Hidden Layers=(50,)
# Accuracy: 0.9205607476635514
# Confusion Matrix:
# [[105  10]
#  [  7  92]]
#
#
# Configuration 7: Activation=identity, Solver=sgd, Hidden Layers=(100,)
# Accuracy: 0.9205607476635514
# Confusion Matrix:
# [[104  11]
#  [  6  93]]
#
#
# Configuration 8: Activation=identity, Solver=sgd, Hidden Layers=(50, 50)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[106   9]
#  [  7  92]]
#
#
# Configuration 9: Activation=identity, Solver=sgd, Hidden Layers=(100, 50)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[105  10]
#  [  6  93]]
#
#
# Configuration 10: Activation=identity, Solver=sgd, Hidden Layers=(100, 100)
# Accuracy: 0.9299065420560748
# Confusion Matrix:
# [[106   9]
#  [  6  93]]
#
#
# Configuration 11: Activation=identity, Solver=adam, Hidden Layers=(50,)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[106   9]
#  [  7  92]]
#
#
# Configuration 12: Activation=identity, Solver=adam, Hidden Layers=(100,)
# Accuracy: 0.9392523364485982
# Confusion Matrix:
# [[108   7]
#  [  6  93]]
#
#
# Configuration 13: Activation=identity, Solver=adam, Hidden Layers=(50, 50)
# Accuracy: 0.9345794392523364
# Confusion Matrix:
# [[107   8]
#  [  6  93]]
#
#
# Configuration 14: Activation=identity, Solver=adam, Hidden Layers=(100, 50)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[106   9]
#  [  7  92]]
#
#
# Configuration 15: Activation=identity, Solver=adam, Hidden Layers=(100, 100)
# Accuracy: 0.9299065420560748
# Confusion Matrix:
# [[106   9]
#  [  6  93]]
#
#
# Configuration 16: Activation=logistic, Solver=lbfgs, Hidden Layers=(50,)
# Accuracy: 0.9766355140186916
# Confusion Matrix:
# [[114   1]
#  [  4  95]]
#
#
# Configuration 17: Activation=logistic, Solver=lbfgs, Hidden Layers=(100,)
# Accuracy: 0.9626168224299065
# Confusion Matrix:
# [[113   2]
#  [  6  93]]
#
#
# Configuration 18: Activation=logistic, Solver=lbfgs, Hidden Layers=(50, 50)
# Accuracy: 0.9626168224299065
# Confusion Matrix:
# [[111   4]
#  [  4  95]]
#
#
# Configuration 19: Activation=logistic, Solver=lbfgs, Hidden Layers=(100, 50)
# Accuracy: 0.9392523364485982
# Confusion Matrix:
# [[111   4]
#  [  9  90]]
#
#
# Configuration 20: Activation=logistic, Solver=lbfgs, Hidden Layers=(100, 100)
# Accuracy: 0.9532710280373832
# Confusion Matrix:
# [[111   4]
#  [  6  93]]
#
#
# Configuration 21: Activation=logistic, Solver=sgd, Hidden Layers=(50,)
# Accuracy: 0.883177570093458
# Confusion Matrix:
# [[108   7]
#  [ 18  81]]
#
#
# Configuration 22: Activation=logistic, Solver=sgd, Hidden Layers=(100,)
# Accuracy: 0.883177570093458
# Confusion Matrix:
# [[108   7]
#  [ 18  81]]
#
#
# Configuration 23: Activation=logistic, Solver=sgd, Hidden Layers=(50, 50)
# Accuracy: 0.5373831775700935
# Confusion Matrix:
# [[115   0]
#  [ 99   0]]
#
#
# Configuration 24: Activation=logistic, Solver=sgd, Hidden Layers=(100, 50)
# Accuracy: 0.5373831775700935
# Confusion Matrix:
# [[115   0]
#  [ 99   0]]
#
#
# Configuration 25: Activation=logistic, Solver=sgd, Hidden Layers=(100, 100)
# Accuracy: 0.5373831775700935
# Confusion Matrix:
# [[115   0]
#  [ 99   0]]
#
#
# Configuration 26: Activation=logistic, Solver=adam, Hidden Layers=(50,)
# Accuracy: 0.9205607476635514
# Confusion Matrix:
# [[104  11]
#  [  6  93]]
#
#
# Configuration 27: Activation=logistic, Solver=adam, Hidden Layers=(100,)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[106   9]
#  [  7  92]]
#
#
# Configuration 28: Activation=logistic, Solver=adam, Hidden Layers=(50, 50)
# Accuracy: 0.9345794392523364
# Confusion Matrix:
# [[107   8]
#  [  6  93]]
#
#
# Configuration 29: Activation=logistic, Solver=adam, Hidden Layers=(100, 50)
# Accuracy: 0.9345794392523364
# Confusion Matrix:
# [[104  11]
#  [  3  96]]
#
#
# Configuration 30: Activation=logistic, Solver=adam, Hidden Layers=(100, 100)
# Accuracy: 0.9392523364485982
# Confusion Matrix:
# [[105  10]
#  [  3  96]]
#
#
# Configuration 31: Activation=tanh, Solver=lbfgs, Hidden Layers=(50,)
# Accuracy: 0.9719626168224299
# Confusion Matrix:
# [[112   3]
#  [  3  96]]
#
#
# Configuration 32: Activation=tanh, Solver=lbfgs, Hidden Layers=(100,)
# Accuracy: 0.9579439252336449
# Confusion Matrix:
# [[112   3]
#  [  6  93]]
#
#
# Configuration 33: Activation=tanh, Solver=lbfgs, Hidden Layers=(50, 50)
# Accuracy: 0.9672897196261683
# Confusion Matrix:
# [[110   5]
#  [  2  97]]
#
#
# Configuration 34: Activation=tanh, Solver=lbfgs, Hidden Layers=(100, 50)
# Accuracy: 0.9672897196261683
# Confusion Matrix:
# [[113   2]
#  [  5  94]]
#
#
# Configuration 35: Activation=tanh, Solver=lbfgs, Hidden Layers=(100, 100)
# Accuracy: 0.9626168224299065
# Confusion Matrix:
# [[110   5]
#  [  3  96]]
#
#
# Configuration 36: Activation=tanh, Solver=sgd, Hidden Layers=(50,)
# Accuracy: 0.9205607476635514
# Confusion Matrix:
# [[105  10]
#  [  7  92]]
#
#
# Configuration 37: Activation=tanh, Solver=sgd, Hidden Layers=(100,)
# Accuracy: 0.9205607476635514
# Confusion Matrix:
# [[104  11]
#  [  6  93]]
#
#
# Configuration 38: Activation=tanh, Solver=sgd, Hidden Layers=(50, 50)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[106   9]
#  [  7  92]]
#
#
# Configuration 39: Activation=tanh, Solver=sgd, Hidden Layers=(100, 50)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[105  10]
#  [  6  93]]
#
#
# Configuration 40: Activation=tanh, Solver=sgd, Hidden Layers=(100, 100)
# Accuracy: 0.9299065420560748
# Confusion Matrix:
# [[106   9]
#  [  6  93]]
#
#
# Configuration 41: Activation=tanh, Solver=adam, Hidden Layers=(50,)
# Accuracy: 0.9345794392523364
# Confusion Matrix:
# [[107   8]
#  [  6  93]]
#
#
# Configuration 42: Activation=tanh, Solver=adam, Hidden Layers=(100,)
# Accuracy: 0.9299065420560748
# Confusion Matrix:
# [[107   8]
#  [  7  92]]
#
#
# Configuration 43: Activation=tanh, Solver=adam, Hidden Layers=(50, 50)
# Accuracy: 0.9345794392523364
# Confusion Matrix:
# [[106   9]
#  [  5  94]]
#
#
# Configuration 44: Activation=tanh, Solver=adam, Hidden Layers=(100, 50)
# Accuracy: 0.9392523364485982
# Confusion Matrix:
# [[105  10]
#  [  3  96]]
#
#
# Configuration 45: Activation=tanh, Solver=adam, Hidden Layers=(100, 100)
# Accuracy: 0.9626168224299065
# Confusion Matrix:
# [[111   4]
#  [  4  95]]
#
#
# Configuration 46: Activation=relu, Solver=lbfgs, Hidden Layers=(50,)
# Accuracy: 0.9532710280373832
# Confusion Matrix:
# [[111   4]
#  [  6  93]]
#
#
# Configuration 47: Activation=relu, Solver=lbfgs, Hidden Layers=(100,)
# Accuracy: 0.9579439252336449
# Confusion Matrix:
# [[112   3]
#  [  6  93]]
#
#
# Configuration 48: Activation=relu, Solver=lbfgs, Hidden Layers=(50, 50)
# Accuracy: 0.9719626168224299
# Confusion Matrix:
# [[112   3]
#  [  3  96]]
#
#
# Configuration 49: Activation=relu, Solver=lbfgs, Hidden Layers=(100, 50)
# Accuracy: 0.9485981308411215
# Confusion Matrix:
# [[110   5]
#  [  6  93]]
#
#
# Configuration 50: Activation=relu, Solver=lbfgs, Hidden Layers=(100, 100)
# Accuracy: 0.9626168224299065
# Confusion Matrix:
# [[112   3]
#  [  5  94]]
#
#
# Configuration 51: Activation=relu, Solver=sgd, Hidden Layers=(50,)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[105  10]
#  [  6  93]]
#
#
# Configuration 52: Activation=relu, Solver=sgd, Hidden Layers=(100,)
# Accuracy: 0.9205607476635514
# Confusion Matrix:
# [[104  11]
#  [  6  93]]
#
#
# Configuration 53: Activation=relu, Solver=sgd, Hidden Layers=(50, 50)
# Accuracy: 0.9299065420560748
# Confusion Matrix:
# [[106   9]
#  [  6  93]]
#
#
# Configuration 54: Activation=relu, Solver=sgd, Hidden Layers=(100, 50)
# Accuracy: 0.9205607476635514
# Confusion Matrix:
# [[104  11]
#  [  6  93]]
#
#
# Configuration 55: Activation=relu, Solver=sgd, Hidden Layers=(100, 100)
# Accuracy: 0.9252336448598131
# Confusion Matrix:
# [[105  10]
#  [  6  93]]
#
#
# Configuration 56: Activation=relu, Solver=adam, Hidden Layers=(50,)
# Accuracy: 0.9439252336448598
# Confusion Matrix:
# [[107   8]
#  [  4  95]]
#
#
# Configuration 57: Activation=relu, Solver=adam, Hidden Layers=(100,)
# Accuracy: 0.9345794392523364
# Confusion Matrix:
# [[106   9]
#  [  5  94]]
#
#
# Configuration 58: Activation=relu, Solver=adam, Hidden Layers=(50, 50)
# Accuracy: 0.9485981308411215
# Confusion Matrix:
# [[110   5]
#  [  6  93]]
#
#
# Configuration 59: Activation=relu, Solver=adam, Hidden Layers=(100, 50)
# Accuracy: 0.9672897196261683
# Confusion Matrix:
# [[109   6]
#  [  1  98]]
#
#
# Configuration 60: Activation=relu, Solver=adam, Hidden Layers=(100, 100)
# Accuracy: 0.9672897196261683
# Confusion Matrix:
# [[112   3]
#  [  4  95]]
#
#
#    activation solver hidden_layers  accuracy
# 0    identity  lbfgs         (50,)  0.915888
# 1    identity  lbfgs        (100,)  0.915888
# 2    identity  lbfgs      (50, 50)  0.915888
# 3    identity  lbfgs     (100, 50)  0.915888
# 4    identity  lbfgs    (100, 100)  0.915888
# 5    identity    sgd         (50,)  0.920561
# 6    identity    sgd        (100,)  0.920561
# 7    identity    sgd      (50, 50)  0.925234
# 8    identity    sgd     (100, 50)  0.925234
# 9    identity    sgd    (100, 100)  0.929907
# 10   identity   adam         (50,)  0.925234
# 11   identity   adam        (100,)  0.939252
# 12   identity   adam      (50, 50)  0.934579
# 13   identity   adam     (100, 50)  0.925234
# 14   identity   adam    (100, 100)  0.929907
# 15   logistic  lbfgs         (50,)  0.976636
# 16   logistic  lbfgs        (100,)  0.962617
# 17   logistic  lbfgs      (50, 50)  0.962617
# 18   logistic  lbfgs     (100, 50)  0.939252
# 19   logistic  lbfgs    (100, 100)  0.953271
# 20   logistic    sgd         (50,)  0.883178
# 21   logistic    sgd        (100,)  0.883178
# 22   logistic    sgd      (50, 50)  0.537383
# 23   logistic    sgd     (100, 50)  0.537383
# 24   logistic    sgd    (100, 100)  0.537383
# 25   logistic   adam         (50,)  0.920561
# 26   logistic   adam        (100,)  0.925234
# 27   logistic   adam      (50, 50)  0.934579
# 28   logistic   adam     (100, 50)  0.934579
# 29   logistic   adam    (100, 100)  0.939252
# 30       tanh  lbfgs         (50,)  0.971963
# 31       tanh  lbfgs        (100,)  0.957944
# 32       tanh  lbfgs      (50, 50)  0.967290
# 33       tanh  lbfgs     (100, 50)  0.967290
# 34       tanh  lbfgs    (100, 100)  0.962617
# 35       tanh    sgd         (50,)  0.920561
# 36       tanh    sgd        (100,)  0.920561
# 37       tanh    sgd      (50, 50)  0.925234
# 38       tanh    sgd     (100, 50)  0.925234
# 39       tanh    sgd    (100, 100)  0.929907
# 40       tanh   adam         (50,)  0.934579
# 41       tanh   adam        (100,)  0.929907
# 42       tanh   adam      (50, 50)  0.934579
# 43       tanh   adam     (100, 50)  0.939252
# 44       tanh   adam    (100, 100)  0.962617
# 45       relu  lbfgs         (50,)  0.953271
# 46       relu  lbfgs        (100,)  0.957944
# 47       relu  lbfgs      (50, 50)  0.971963
# 48       relu  lbfgs     (100, 50)  0.948598
# 49       relu  lbfgs    (100, 100)  0.962617
# 50       relu    sgd         (50,)  0.925234
# 51       relu    sgd        (100,)  0.920561
# 52       relu    sgd      (50, 50)  0.929907
# 53       relu    sgd     (100, 50)  0.920561
# 54       relu    sgd    (100, 100)  0.925234
# 55       relu   adam         (50,)  0.943925
# 56       relu   adam        (100,)  0.934579
# 57       relu   adam      (50, 50)  0.948598
# 58       relu   adam     (100, 50)  0.967290
# 59       relu   adam    (100, 100)  0.967290

# %% [markdown]
# **6. Indicar los hiperparámetros que por el momento permiten obtener la red con mayor accuracy**

# %%
# Encontrar el modelo con mayor accuracy
best_model = results_df.loc[results_df['accuracy'].idxmax()]

print("Mejor Modelo:")
print(f"Activation: {best_model['activation']}")
print(f"Solver: {best_model['solver']}")
print(f"Hidden Layers: {best_model['hidden_layers']}")
print(f"Accuracy: {best_model['accuracy']}")
# Out:
# Mejor Modelo:
# Activation: logistic
# Solver: lbfgs
# Hidden Layers: (50,)
# Accuracy: 0.9766355140186916

# %% [markdown]
# **6. Seleccione uno de los hiperparámetros disponibles en la documentación.**

# %%
# Selecciona los mejores hiperparámetros obtenidos previamente
best_activation = best_model['activation']
best_solver = best_model['solver']
best_hidden_layers = best_model['hidden_layers']

# Definir los valores del hiperparámetro alpha a probar
alpha_values = [0.0001, 0.001, 0.01]

# Lista para almacenar los resultados
alpha_results = []

# Probar diferentes valores de alpha
for alpha in alpha_values:
    mlp = MLPClassifier(
        activation=best_activation,
        solver=best_solver,
        hidden_layer_sizes=best_hidden_layers,
        alpha=alpha,
        random_state=123
    )
    mlp.fit(X_train, y_train)
    y_pred = mlp.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    alpha_results.append({
        'alpha': alpha,
        'accuracy': accuracy,
        'conf_matrix': conf_matrix
    })

# Mostrar los resultados en una tabla
alpha_results_df = pd.DataFrame(alpha_results, columns=['alpha', 'accuracy', 'conf_matrix'])
print(alpha_results_df)

# Mostrar las matrices de confusión y los accuracies obtenidos
for result in alpha_results:
    print(f"Alpha: {result['alpha']}")
    print(f"Accuracy: {result['accuracy']}")
    print("Confusion Matrix:")
    print(result['conf_matrix'])
    print("\n")

# Análisis final
print("Análisis del impacto del hiperparámetro 'alpha':")
for result in alpha_results:
    print(f"Con alpha={result['alpha']}, la precisión del modelo fue {result['accuracy']:.4f}.")

# Comparación con el mejor accuracy obtenido anteriormente
best_accuracy_prev = best_model['accuracy']
for result in alpha_results:
    print(f"Comparando con el mejor accuracy anterior ({best_accuracy_prev:.4f}):")
    if result['accuracy'] > best_accuracy_prev:
        print(f"Alpha={result['alpha']} mejora la precisión del modelo.")
    elif result['accuracy'] < best_accuracy_prev:
        print(f"Alpha={result['alpha']} empeora la precisión del modelo.")
    else:
        print(f"Alpha={result['alpha']} mantiene la precisión del modelo.")
# Out:
#     alpha  accuracy          conf_matrix
# 0  0.0001  0.976636  [[114, 1], [4, 95]]
# 1  0.0010  0.962617  [[111, 4], [4, 95]]
# 2  0.0100  0.962617  [[111, 4], [4, 95]]
# Alpha: 0.0001
# Accuracy: 0.9766355140186916
# Confusion Matrix:
# [[114   1]
#  [  4  95]]
#
#
# Alpha: 0.001
# Accuracy: 0.9626168224299065
# Confusion Matrix:
# [[111   4]
#  [  4  95]]
#
#
# Alpha: 0.01
# Accuracy: 0.9626168224299065
# Confusion Matrix:
# [[111   4]
#  [  4  95]]
#
#
# Análisis del impacto del hiperparámetro 'alpha':
# Con alpha=0.0001, la precisión del modelo fue 0.9766.
# Con alpha=0.001, la precisión del modelo fue 0.9626.
# Con alpha=0.01, la precisión del modelo fue 0.9626.
# Comparando con el mejor accuracy anterior (0.9766):
# Alpha=0.0001 mantiene la precisión del modelo.
# Comparando con el mejor accuracy anterior (0.9766):
# Alpha=0.001 empeora la precisión del modelo.
# Comparando con el mejor accuracy anterior (0.9766):
# Alpha=0.01 empeora la precisión del modelo.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
